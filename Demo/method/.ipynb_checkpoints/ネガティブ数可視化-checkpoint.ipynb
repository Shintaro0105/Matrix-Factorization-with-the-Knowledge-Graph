# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = df1 = pd.read_csv('dim128-30-30_1.csv')

# %%
x=df['num_negatives']
p10=df['pre10']
r10=df['rec10']
p20=df['pre20']
r20=df['rec20']

# %%
plt.xlabel("#Negatives")
plt.ylabel("Precision@10")
plt.plot(x,p10,marker="o")

# %%
plt.xlabel("#Negatives")
plt.ylabel("Precision@20")
plt.plot(x,p20,marker="o")

# %%
plt.xlabel("#Negatives")
plt.ylabel("Recall@10")
plt.plot(x,r10,marker="o")

# %%
plt.xlabel("#Negatives")
plt.ylabel("Recall@20")
plt.plot(x,r20,marker="o")
